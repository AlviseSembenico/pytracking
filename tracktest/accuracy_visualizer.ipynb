# %%
from lib import *

# %%
dimp_dir = os.path.abspath('dimp_thor_no_reps')
OTB100 = 'C:\\Users\\alvis\\Documents\\Thesis\\pysot\\testing_dataset\\OTB100'


dimp_out = set(os.listdir(dimp_dir))
dimp_out
dimp_out = set(filter(lambda x: len(x.split('.')) > 1 and x.split('.')[1] == 'txt' and '_' not in x, dimp_out))
list(dimp_out)[:10]

base_dimp = os.path.abspath('dimp')

# %%
dimp_acc, metrics_result = read_bb(dimp_out, OTB100, dimp_dir)

# %%
show_acc_plot_compare('biker', OTB100, dimp_dir, base_dimp)
